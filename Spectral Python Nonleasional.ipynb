# %%
# %gui wx

# %%
from spectral import *
import matplotlib as mpl
import pylab as plt
mpl.rcParams["backend"] = "WX"
import numpy as np

# %%
img_nonleasional = open_image(r'HSI1\HSI1_Nonlesional\1N_FOV2out.hdr')

# %%
lib_nonleasional = envi.open(r'HSI1\HSI1_Nonlesional\1N_FOV2out.hdr')

# %%
lib_nonleasional
# Out:
# 	Data Source:   '.\HSI1\HSI1_Nonlesional\1N_FOV2out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_nonleasional.shape
# Out:
# (501, 502, 38)

# %%
pixel_nonleasional = img_nonleasional[50,50]

# %%
pixel_nonleasional.shape
# Out:
# (38,)

# %%
arr_nonleasional = img_nonleasional.load()
# Out:
# C:\ProgramData\Anaconda3\envs\hyperspyenv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   """Entry point for launching an IPython kernel.

# %%
print(arr_nonleasional.info())
# Out:
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Data format:   float32

# %%
arr_nonleasional.shape
# Out:
# (501, 502, 38)

# %%
view_nonleasional = imshow(img_nonleasional)

# %%
print(pixel_nonleasional)
# Out:
# [562 548 508 454 409 370 322 324 311 303 294 279 270 272 273 275 272 269
#  261 247 247 247 245 243 231 229 227 215 217 207 212 201 192 194 191 188
#  184 187]

# %%
cube = view_cube(img_nonleasional, bands=[2, 16, 35])
# Out:
# Mouse Functions:
# ----------------
# left-click & drag        ->   Rotate cube
# CTRL+left-click & drag   ->   Zoom in/out
# SHIFT+left-click & drag  ->  Pan
#
# Keybinds:
# ---------
# l       -> toggle light
# t/g     -> stretch/compress z-dimension
# h       -> print help message
# q       -> close window

# %%
spectrum=[]
for i in range(360, 385, 5):
    spectra = i
    spectrum.append(spectra)
for k in range(390, 555, 5):
    spectra = k
    spectrum.append(spectra)
print(spectrum)
spectrum = np.asarray(spectrum)
# Out:
# [360, 365, 370, 375, 380, 390, 395, 400, 405, 410, 415, 420, 425, 430, 435, 440, 445, 450, 455, 460, 465, 470, 475, 480, 485, 490, 495, 500, 505, 510, 515, 520, 525, 530, 535, 540, 545, 550]

# %%
spectrum.shape
# Out:
# (38,)

# %%
plt.plot(spectrum, pixel_nonleasional)
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.title('Spectral Distribution of "Nonlesional" Sample')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')

# %%
img_nonleasional2 = open_image(r'HSI12\HSI12_Nonlesional\12N_FOV3out.hdr')

# %%
lib_nonleasional2 = envi.open(r'HSI12\HSI12_Nonlesional\12N_FOV3out.hdr')

# %%
lib_nonleasional2
# Out:
# 	Data Source:   '.\HSI12\HSI12_Nonlesional\12N_FOV3out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_nonleasional2.shape
# Out:
# (501, 502, 38)

# %%
pixel_nonleasional2 = img_nonleasional2[150,455]

# %%
img_nonleasional3 = open_image(r'HSI8\HSI8_Nonlesional\8N_FOV2out.hdr')

# %%
lib_nonleasional3 = envi.open(r'HSI8\HSI8_Nonlesional\8N_FOV2out.hdr')

# %%
lib_nonleasional3
# Out:
# 	Data Source:   '.\HSI8\HSI8_Nonlesional\8N_FOV2out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_nonleasional3.shape
# Out:
# (501, 502, 38)

# %%
pixel_nonleasional3 = img_nonleasional3[277,62]

# %%
img_nonleasional4 = open_image(r'HSI4\HSI4_Nonlesional\4N_FOV5out.hdr')

# %%
lib_nonleasional4 = envi.open(r'HSI4\HSI4_Nonlesional\4N_FOV5out.hdr')

# %%
lib_nonleasional4
# Out:
# 	Data Source:   '.\HSI4\HSI4_Nonlesional\4N_FOV5out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_nonleasional4.shape
# Out:
# (501, 502, 38)

# %%
pixel_nonleasional4 = img_nonleasional[489,21]

# %%
plt.plot(spectrum, pixel_nonleasional, color='black')
plt.plot(spectrum, pixel_nonleasional2, color='purple')
plt.plot(spectrum, pixel_nonleasional3, color='orange')
plt.plot(spectrum, pixel_nonleasional4, color='gray')
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.title('Spectral Distribution of "Nonlesional" Samples')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')

# %%
pixel_nonleasional_3 = img_nonleasional[100,400]

# %%
plt.plot(spectrum, pixel_nonleasional_3)
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.title('Spectral Distribution of "Nonlesional" Sample')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')
