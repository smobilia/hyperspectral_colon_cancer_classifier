# %%
# %gui wx

# %%
from spectral import *
import matplotlib as mpl
import pylab as plt
from OpenGL.GL import *
mpl.rcParams["backend"] = "WX"
import numpy as np

# %%
img_misclass_leasion = open_image(r'HSI6\HSI6_Lesional\6L_FOV2out.hdr')

# %%
lib_misclass_leasion = envi.open(r'HSI6\HSI6_Lesional\6L_FOV2out.hdr')

# %%
lib_misclass_leasion
# Out:
# 	Data Source:   '.\HSI6\HSI6_Lesional\6L_FOV2out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_leasion.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_leasion = img_misclass_leasion[50,50]

# %%
pixel_misclass_leasion.shape
# Out:
# (38,)

# %%
arr_misclass_leasion = img_misclass_leasion.load()
# Out:
# C:\ProgramData\Anaconda3\envs\hyperspyenv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   """Entry point for launching an IPython kernel.

# %%
print(arr_misclass_leasion.info())
# Out:
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Data format:   float32

# %%
arr_misclass_leasion.shape
# Out:
# (501, 502, 38)

# %%
view_misclass_leasion = imshow(img_misclass_leasion)

# %%
print(pixel_misclass_leasion)
# Out:
# [53 65 61 62 45 31 28 22 19 16 24 22 28 31 39 51 51 54 56 59 57 56 59 53
#  54 50 46 46 39 39 34 30 28 31 30 28 24 26]

# %%
cube = view_cube(img_misclass_leasion, bands=[2, 16, 35])
# Out:
# C:\ProgramData\Anaconda3\envs\hyperspyenv\lib\site-packages\spectral\graphics\graphics.py:792: UserWarning:
# There is no current wx.App object - creating one now.
#   UserWarning)

# %%
cube = view_cube(img_misclass_leasion, bands=[29, 19, 9])

# %%
spectrum=[]
for i in range(360, 385, 5):
    spectra = i
    spectrum.append(spectra)
for k in range(390, 555, 5):
    spectra = k
    spectrum.append(spectra)
print(spectrum)
spectrum = np.asarray(spectrum)
# Out:
# [360, 365, 370, 375, 380, 390, 395, 400, 405, 410, 415, 420, 425, 430, 435, 440, 445, 450, 455, 460, 465, 470, 475, 480, 485, 490, 495, 500, 505, 510, 515, 520, 525, 530, 535, 540, 545, 550]

# %%
spectrum[5]
# Out:
# 390

# %%
spectrum[17]
# Out:
# 450

# %%
spectrum.shape
# Out:
# (38,)

# %%
plt.plot(spectrum, pixel_misclass_leasion, color='black')
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')
plt.show()

# %%
patient6_leasion1 = open_image(r'HSI6\HSI6_Lesional\6L_FOV2out.hdr')

# %%
lib_patient6_leasion1 = envi.open(r'HSI6\HSI6_Lesional\6L_FOV2out.hdr')

# %%
lib_patient6_leasion1
# Out:
# 	Data Source:   '.\HSI6\HSI6_Lesional\6L_FOV2out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
patient6_leasion1.shape
# Out:
# (501, 502, 38)

# %%
pixel_patient6_leasion1_2 = patient6_leasion1[250,350]
pixel_patient6_leasion1_3 = patient6_leasion1[450,120]
pixel_patient6_leasion1_4 = patient6_leasion1[150,39]
pixel_patient6_leasion1_5 = patient6_leasion1[375,422]

# %%
patient6_leasion2 = open_image(r'HSI6\HSI6_Lesional\6L_FOV3out.hdr')

# %%
lib_patient6_leasion2 = envi.open(r'HSI6\HSI6_Lesional\6L_FOV3out.hdr')

# %%
lib_patient6_leasion2
# Out:
# 	Data Source:   '.\HSI6\HSI6_Lesional\6L_FOV3out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
patient6_leasion2.shape
# Out:
# (501, 502, 38)

# %%
pixel_patient6_leasion2_2 = patient6_leasion2[250,350]
pixel_patient6_leasion2_3 = patient6_leasion2[450,120]
pixel_patient6_leasion2_4 = patient6_leasion2[150,39]
pixel_patient6_leasion2_5 = patient6_leasion2[375,422]

# %%
patient6_leasion3 = open_image(r'HSI6\HSI6_Lesional\6L_FOV4out.hdr')

# %%
lib_patient6_leasion3 = envi.open(r'HSI6\HSI6_Lesional\6L_FOV4out.hdr')

# %%
lib_patient6_leasion3
# Out:
# 	Data Source:   '.\HSI6\HSI6_Lesional\6L_FOV4out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
patient6_leasion3.shape
# Out:
# (501, 502, 38)

# %%
pixel_patient6_leasion3_2 = patient6_leasion3[250,350]
pixel_patient6_leasion3_3 = patient6_leasion3[450,120]
pixel_patient6_leasion3_4 = patient6_leasion3[150,39]
pixel_patient6_leasion3_5 = patient6_leasion3[375,422]

# %%
patient6_leasion4 = open_image(r'HSI6\HSI6_Lesional\6L_FOV5out.hdr')

# %%
lib_patient6_leasion4 = envi.open(r'HSI6\HSI6_Lesional\6L_FOV5out.hdr')

# %%
lib_patient6_leasion4
# Out:
# 	Data Source:   '.\HSI6\HSI6_Lesional\6L_FOV5out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
patient6_leasion4.shape
# Out:
# (501, 502, 38)

# %%
pixel_patient6_leasion4_2 = patient6_leasion4[250,350]
pixel_patient6_leasion4_3 = patient6_leasion4[450,120]
pixel_patient6_leasion4_4 = patient6_leasion4[150,39]
pixel_patient6_leasion4_5 = patient6_leasion4[375,422]

# %%
fig = plt.figure(figsize=(6.5, 5))
ax = fig.add_subplot(111)

ax.plot(spectrum, pixel_patient6_leasion1_2, color='purple')
ax.plot(spectrum, pixel_patient6_leasion1_3, color='purple')
ax.plot(spectrum, pixel_patient6_leasion1_4, color='purple')
ax.plot(spectrum, pixel_patient6_leasion1_5, color='purple')
ax.plot(spectrum, pixel_patient6_leasion2_2, color='orange')
ax.plot(spectrum, pixel_patient6_leasion2_3, color='orange')
ax.plot(spectrum, pixel_patient6_leasion2_4, color='orange')
ax.plot(spectrum, pixel_patient6_leasion2_5, color='orange')
ax.plot(spectrum, pixel_patient6_leasion3_2, color='cyan')
ax.plot(spectrum, pixel_patient6_leasion3_3, color='cyan')
ax.plot(spectrum, pixel_patient6_leasion3_4, color='cyan')
ax.plot(spectrum, pixel_patient6_leasion3_5, color='cyan')
ax.plot(spectrum, pixel_patient6_leasion4_2, color='red')
ax.plot(spectrum, pixel_patient6_leasion4_3, color='red')
ax.plot(spectrum, pixel_patient6_leasion4_4, color='red')
ax.plot(spectrum, pixel_patient6_leasion4_5, color='red')
ax.set_xlabel('Wavelength')
ax.set_ylabel('Spectral Intensity (14-bit)')
ax.set_xlim(left=350)
ax.set_xlim(right=750)
ax.axvline(x=450, color='blue', linestyle='--')
ax.axvline(x=485, color='blue', linestyle='--')
ax.text(454, 25, 'Blue', fontsize=11)
ax.text(452, 15, 'Light', fontsize=11)
ax.annotate('', xy=(450, 9), xytext=(485, 9), arrowprops=dict(arrowstyle="<->",color='blue', lw=2.5))
ax.axvline(x=500, color='green', linestyle='--')
ax.axvline(x=565, color='green', linestyle='--')
ax.text(513, 160, 'Green', fontsize=11)
ax.text(517, 150, 'Light', fontsize=11)
ax.annotate('', xy=(500, 144), xytext=(565, 144), arrowprops=dict(arrowstyle="<->",color='green', lw=2.5))
ax.axvline(x=625, color='red', linestyle='--')
ax.axvline(x=740, color='red', linestyle='--')
ax.text(672, 160, 'Red', fontsize=11)
ax.text(669, 150, 'Light', fontsize=11)
ax.annotate('', xy=(625, 144), xytext=(740, 144), arrowprops=dict(arrowstyle="<->",color='red', lw=2.5))

plt.show()

# %%
patient6_nonleasion1 = open_image(r'HSI6\HSI6_Nonlesional\6N_FOV2out.hdr')

# %%
lib_patient6_nonleasion1 = envi.open(r'HSI6\HSI6_Nonlesional\6N_FOV2out.hdr')

# %%
lib_patient6_nonleasion1
# Out:
# 	Data Source:   '.\HSI6\HSI6_Nonlesional\6N_FOV2out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
patient6_nonleasion1.shape
# Out:
# (501, 502, 38)

# %%
pixel_patient6_nonleasion1_2 = patient6_nonleasion1[250,350]
pixel_patient6_nonleasion1_3 = patient6_nonleasion1[450,120]
pixel_patient6_nonleasion1_4 = patient6_nonleasion1[150,39]
pixel_patient6_nonleasion1_5 = patient6_nonleasion1[375,422]

# %%
patient6_nonleasion2 = open_image(r'HSI6\HSI6_Nonlesional\6N_FOV3out.hdr')

# %%
lib_patient6_nonleasion2 = envi.open(r'HSI6\HSI6_Nonlesional\6N_FOV3out.hdr')

# %%
lib_patient6_nonleasion2
# Out:
# 	Data Source:   '.\HSI6\HSI6_Nonlesional\6N_FOV3out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
patient6_nonleasion2.shape
# Out:
# (501, 502, 38)

# %%
pixel_patient6_nonleasion2_2 = patient6_nonleasion2[250,350]
pixel_patient6_nonleasion2_3 = patient6_nonleasion2[450,120]
pixel_patient6_nonleasion2_4 = patient6_nonleasion2[150,39]
pixel_patient6_nonleasion2_5 = patient6_nonleasion2[375,422]

# %%
patient6_nonleasion3 = open_image(r'HSI6\HSI6_Nonlesional\6N_FOV4out.hdr')

# %%
lib_patient6_nonleasion3 = envi.open(r'HSI6\HSI6_Nonlesional\6N_FOV4out.hdr')

# %%
lib_patient6_nonleasion3
# Out:
# 	Data Source:   '.\HSI6\HSI6_Nonlesional\6N_FOV4out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
patient6_nonleasion3.shape
# Out:
# (501, 502, 38)

# %%
pixel_patient6_nonleasion3_2 = patient6_nonleasion3[250,350]
pixel_patient6_nonleasion3_3 = patient6_nonleasion3[450,120]
pixel_patient6_nonleasion3_4 = patient6_nonleasion3[150,39]
pixel_patient6_nonleasion3_5 = patient6_nonleasion3[375,422]

# %%
patient6_nonleasion4 = open_image(r'HSI6\HSI6_Nonlesional\6N_FOV5out.hdr')

# %%
lib_patient6_nonleasion4 = envi.open(r'HSI6\HSI6_Nonlesional\6N_FOV5out.hdr')

# %%
lib_patient6_nonleasion4
# Out:
# 	Data Source:   '.\HSI6\HSI6_Nonlesional\6N_FOV5out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
pixel_patient6_nonleasion4_2 = patient6_nonleasion4[250,350]
pixel_patient6_nonleasion4_3 = patient6_nonleasion4[450,120]
pixel_patient6_nonleasion4_4 = patient6_nonleasion4[150,39]
pixel_patient6_nonleasion4_5 = patient6_nonleasion4[375,422]

# %%
patient6_nonleasion5 = open_image(r'HSI6\HSI6_Nonlesional\6N_FOV6out.hdr')

# %%
lib_patient6_nonleasion5 = envi.open(r'HSI6\HSI6_Nonlesional\6N_FOV6out.hdr')

# %%
lib_patient6_nonleasion5
# Out:
# 	Data Source:   '.\HSI6\HSI6_Nonlesional\6N_FOV6out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
pixel_patient6_nonleasion5_2 = patient6_nonleasion5[250,350]
pixel_patient6_nonleasion5_3 = patient6_nonleasion5[450,120]
pixel_patient6_nonleasion5_4 = patient6_nonleasion5[150,39]
pixel_patient6_nonleasion5_5 = patient6_nonleasion5[375,422]

# %%
patient6_nonleasion6 = open_image(r'HSI6\HSI6_Nonlesional\6N_FOV7out.hdr')

# %%
lib_patient6_nonleasion6 = envi.open(r'HSI6\HSI6_Nonlesional\6N_FOV7out.hdr')

# %%
lib_patient6_nonleasion6
# Out:
# 	Data Source:   '.\HSI6\HSI6_Nonlesional\6N_FOV7out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
pixel_patient6_nonleasion6_2 = patient6_nonleasion6[250,350]
pixel_patient6_nonleasion6_3 = patient6_nonleasion6[450,120]
pixel_patient6_nonleasion6_4 = patient6_nonleasion6[150,39]
pixel_patient6_nonleasion6_5 = patient6_nonleasion6[375,422]

# %%
fig = plt.figure(figsize=(6.5, 5))
ax = fig.add_subplot(111)

ax.plot(spectrum, pixel_patient6_nonleasion1_2, color='purple')
ax.plot(spectrum, pixel_patient6_nonleasion1_3, color='purple')
ax.plot(spectrum, pixel_patient6_nonleasion1_4, color='purple')
ax.plot(spectrum, pixel_patient6_nonleasion1_5, color='purple')
ax.plot(spectrum, pixel_patient6_nonleasion2_2, color='orange')
ax.plot(spectrum, pixel_patient6_nonleasion2_3, color='orange')
ax.plot(spectrum, pixel_patient6_nonleasion2_4, color='orange')
ax.plot(spectrum, pixel_patient6_nonleasion2_5, color='orange')
ax.plot(spectrum, pixel_patient6_nonleasion3_2, color='blue')
ax.plot(spectrum, pixel_patient6_nonleasion3_3, color='blue')
ax.plot(spectrum, pixel_patient6_nonleasion3_4, color='blue')
ax.plot(spectrum, pixel_patient6_nonleasion3_5, color='blue')
ax.plot(spectrum, pixel_patient6_nonleasion4_2, color='red')
ax.plot(spectrum, pixel_patient6_nonleasion4_3, color='red')
ax.plot(spectrum, pixel_patient6_nonleasion4_4, color='red')
ax.plot(spectrum, pixel_patient6_nonleasion4_5, color='red')
ax.plot(spectrum, pixel_patient6_nonleasion5_2, color='black')
ax.plot(spectrum, pixel_patient6_nonleasion5_3, color='black')
ax.plot(spectrum, pixel_patient6_nonleasion5_4, color='black')
ax.plot(spectrum, pixel_patient6_nonleasion5_5, color='black')
ax.plot(spectrum, pixel_patient6_nonleasion6_2, color='green')
ax.plot(spectrum, pixel_patient6_nonleasion6_3, color='green')
ax.plot(spectrum, pixel_patient6_nonleasion6_4, color='green')
ax.plot(spectrum, pixel_patient6_nonleasion6_5, color='green')
ax.set_xlabel('Wavelength')
ax.set_ylabel('Spectral Intensity (14-bit)')
ax.set_xlim(left=350)
ax.set_xlim(right=750)
ax.axvline(x=450, color='blue', linestyle='--')
ax.axvline(x=485, color='blue', linestyle='--')
ax.text(454, 440, 'Blue', fontsize=11)
ax.text(452, 415, 'Light', fontsize=11)
ax.annotate('', xy=(450, 400), xytext=(485, 400), arrowprops=dict(arrowstyle="<->",color='blue', lw=2.5))
ax.axvline(x=500, color='green', linestyle='--')
ax.axvline(x=565, color='green', linestyle='--')
ax.text(513, 440, 'Green', fontsize=11)
ax.text(517, 415, 'Light', fontsize=11)
ax.annotate('', xy=(500, 400), xytext=(565, 400), arrowprops=dict(arrowstyle="<->",color='green', lw=2.5))
ax.axvline(x=625, color='red', linestyle='--')
ax.axvline(x=740, color='red', linestyle='--')
ax.text(672, 440, 'Red', fontsize=11)
ax.text(669, 415, 'Light', fontsize=11)
ax.annotate('', xy=(625, 400), xytext=(740, 400), arrowprops=dict(arrowstyle="<->",color='red', lw=2.5))

plt.show()

# %%
img_misclass_leasion2 = open_image(r'HSI7\HSI7_Nonlesional\7N_FOV6out.hdr')

# %%
lib_misclass_leasion2 = envi.open(r'HSI7\HSI7_Nonlesional\7N_FOV6out.hdr')

# %%
lib_misclass_leasion2
# Out:
# 	Data Source:   '.\HSI7\HSI7_Nonlesional\7N_FOV6out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_leasion2.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_leasion2 = img_misclass_leasion2[250,350]
pixel_misclass_leasion3 = img_misclass_leasion2[450,120]

# %%
img_misclass_leasion3 = open_image(r'HSI6\HSI6_Nonlesional\6N_FOV6out.hdr')

# %%
lib_misclass_leasion3 = envi.open(r'HSI6\HSI6_Nonlesional\6N_FOV6out.hdr')

# %%
lib_misclass_leasion3
# Out:
# 	Data Source:   '.\HSI6\HSI6_Nonlesional\6N_FOV6out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_leasion3.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_leasion4 = img_misclass_leasion3[100,450]
pixel_misclass_leasion5 = img_misclass_leasion3[222,333]

# %%
img_misclass_leasion4 = open_image(r'HSI10\HSI10_Nonlesional\10N_FOV9out.hdr')

# %%
lib_misclass_leasion4 = envi.open(r'HSI10\HSI10_Nonlesional\10N_FOV9out.hdr')

# %%
lib_misclass_leasion4
# Out:
# 	Data Source:   '.\HSI10\HSI10_Nonlesional\10N_FOV9out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_leasion4.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_leasion6 = img_misclass_leasion4[425,361]
pixel_misclass_leasion7 = img_misclass_leasion4[35,42]

# %%
img_misclass_leasion5 = open_image(r'HSI9\HSI9_Nonlesional\9N_FOV7out.hdr')

# %%
lib_misclass_leasion5 = envi.open(r'HSI9\HSI9_Nonlesional\9N_FOV7out.hdr')

# %%
lib_misclass_leasion5
# Out:
# 	Data Source:   '.\HSI9\HSI9_Nonlesional\9N_FOV7out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_leasion5.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_leasion8 = img_misclass_leasion5[197,228]
pixel_misclass_leasion9 = img_misclass_leasion5[359,361]

# %%
plt.plot(spectrum, pixel_misclass_leasion, color='black')
plt.plot(spectrum, pixel_misclass_leasion2, color='purple')
plt.plot(spectrum, pixel_misclass_leasion3, color='orange')
plt.plot(spectrum, pixel_misclass_leasion4, color='green')
plt.plot(spectrum, pixel_misclass_leasion5, color='blue')
plt.plot(spectrum, pixel_misclass_leasion6, color='yellow')
plt.plot(spectrum, pixel_misclass_leasion7, color='magenta')
plt.plot(spectrum, pixel_misclass_leasion8, color='red')
plt.plot(spectrum, pixel_misclass_leasion9, color='cyan')
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.title('Spectral Distribution of Nonlesional (Misclassified as Lesional) Samples')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')

# %%
img_misclass_nonleasion2 = open_image(r'HSI13\HSI13_Lesional\FOV3__13L__out.hdr')

# %%
lib_misclass_nonleasion2 = envi.open(r'HSI13\HSI13_Lesional\FOV3__13L__out.hdr')

# %%
lib_misclass_nonleasion2
# Out:
# 	Data Source:   '.\HSI13\HSI13_Lesional\FOV3__13L__out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_nonleasion2.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_nonleasion2 = img_misclass_nonleasion2[250,350]
pixel_misclass_nonleasion3 = img_misclass_nonleasion2[450,120]

# %%
img_misclass_nonleasion3 = open_image(r'HSI1\HSI1_Lesional\FOV3__1L__out.hdr')

# %%
lib_misclass_nonleasion3 = envi.open(r'HSI1\HSI1_Lesional\FOV3__1L__out.hdr')

# %%
lib_misclass_nonleasion3
# Out:
# 	Data Source:   '.\HSI1\HSI1_Lesional\FOV3__1L__out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_nonleasion3.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_nonleasion4 = img_misclass_nonleasion3[100,450]
pixel_misclass_nonleasion5 = img_misclass_nonleasion3[222,333]

# %%
img_misclass_nonleasion4 = open_image(r'HSI7\HSI7_Lesional\7L_FOV4aout.hdr')

# %%
lib_misclass_nonleasion4 = envi.open(r'HSI7\HSI7_Lesional\7L_FOV4aout.hdr')

# %%
lib_misclass_nonleasion4
# Out:
# 	Data Source:   '.\HSI7\HSI7_Lesional\7L_FOV4aout.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_nonleasion4.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_nonleasion6 = img_misclass_nonleasion4[425,361]
pixel_misclass_nonleasion7 = img_misclass_nonleasion4[35,42]

# %%
img_misclass_nonleasion5 = open_image(r'HSI12\HSI12_Lesional\12L_FOV5out.hdr')

# %%
lib_misclass_nonleasion5 = envi.open(r'HSI12\HSI12_Lesional\12L_FOV5out.hdr')

# %%
lib_misclass_leasion5
# Out:
# 	Data Source:   '.\HSI3\HSI3_Nonlesional\3N_FOV6out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_misclass_nonleasion5.shape
# Out:
# (501, 502, 38)

# %%
pixel_misclass_nonleasion8 = img_misclass_nonleasion5[197,228]
pixel_misclass_nonleasion9 = img_misclass_nonleasion5[359,361]

# %%
plt.plot(spectrum, pixel_misclass_nonleasion2, color='purple')
plt.plot(spectrum, pixel_misclass_nonleasion3, color='orange')
plt.plot(spectrum, pixel_misclass_nonleasion4, color='green')
plt.plot(spectrum, pixel_misclass_nonleasion5, color='blue')
plt.plot(spectrum, pixel_misclass_nonleasion6, color='yellow')
plt.plot(spectrum, pixel_misclass_nonleasion7, color='magenta')
plt.plot(spectrum, pixel_misclass_nonleasion8, color='red')
plt.plot(spectrum, pixel_misclass_nonleasion9, color='black')
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.title('Spectral Distribution of Lesional (Misclassified as Nonlesional) Samples')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')

# %%
img_corclass_nonleasion2 = open_image(r'HSI14\HSI14_Nonlesional\FOV6__14N__out.hdr')

# %%
lib_corclass_nonleasion2 = envi.open(r'HSI14\HSI14_Nonlesional\FOV6__14N__out.hdr')

# %%
lib_corclass_nonleasion2
# Out:
# 	Data Source:   '.\HSI14\HSI14_Nonlesional\FOV6__14N__out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_corclass_nonleasion2.shape
# Out:
# (501, 502, 38)

# %%
pixel_corclass_nonleasion2 = img_corclass_nonleasion2[250,350]
pixel_corclass_nonleasion3 = img_corclass_nonleasion2[450,120]

# %%
img_corclass_nonleasion3 = open_image(r'HSI12\HSI12_Nonlesional\12N_FOV5out.hdr')

# %%
lib_corclass_nonleasion3 = envi.open(r'HSI12\HSI12_Nonlesional\12N_FOV5out.hdr')

# %%
lib_corclass_nonleasion3
# Out:
# 	Data Source:   '.\HSI12\HSI12_Nonlesional\12N_FOV5out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_corclass_nonleasion3.shape
# Out:
# (501, 502, 38)

# %%
pixel_corclass_nonleasion4 = img_corclass_nonleasion3[100,450]
pixel_corclass_nonleasion5 = img_corclass_nonleasion3[222,333]

# %%
img_corclass_nonleasion4 = open_image(r'HSI6\HSI6_Nonlesional\6N_FOV5out.hdr')

# %%
lib_corclass_nonleasion4 = envi.open(r'HSI6\HSI6_Nonlesional\6N_FOV5out.hdr')

# %%
lib_corclass_nonleasion4
# Out:
# 	Data Source:   '.\HSI6\HSI6_Nonlesional\6N_FOV5out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_corclass_nonleasion4.shape
# Out:
# (501, 502, 38)

# %%
pixel_corclass_nonleasion6 = img_corclass_nonleasion4[425,361]
pixel_corclass_nonleasion7 = img_corclass_nonleasion4[35,42]

# %%
img_corclass_nonleasion5 = open_image(r'HSI10\HSI10_Nonlesional\10N_FOV5out.hdr')

# %%
lib_corclass_nonleasion5 = envi.open(r'HSI10\HSI10_Nonlesional\10N_FOV5out.hdr')

# %%
lib_corclass_nonleasion5
# Out:
# 	Data Source:   '.\HSI10\HSI10_Nonlesional\10N_FOV5out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_corclass_nonleasion5.shape
# Out:
# (501, 502, 38)

# %%
pixel_corclass_nonleasion8 = img_corclass_nonleasion5[197,228]
pixel_corclass_nonleasion9 = img_corclass_nonleasion5[359,361]

# %%
plt.plot(spectrum, pixel_corclass_nonleasion2, color='purple')
plt.plot(spectrum, pixel_corclass_nonleasion3, color='orange')
plt.plot(spectrum, pixel_corclass_nonleasion4, color='green')
plt.plot(spectrum, pixel_corclass_nonleasion5, color='blue')
plt.plot(spectrum, pixel_corclass_nonleasion6, color='yellow')
plt.plot(spectrum, pixel_corclass_nonleasion7, color='magenta')
plt.plot(spectrum, pixel_corclass_nonleasion8, color='red')
plt.plot(spectrum, pixel_corclass_nonleasion9, color='black')
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.title('Spectral Distribution of Nonlesional (Correct) Samples')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')

# %%
img_corclass_leasion2 = open_image(r'HSI4\HSI4_Lesional\4L_FOV6out.hdr')

# %%
lib_corclass_leasion2 = envi.open(r'HSI4\HSI4_Lesional\4L_FOV6out.hdr')

# %%
lib_corclass_leasion2
# Out:
# 	Data Source:   '.\HSI4\HSI4_Lesional\4L_FOV6out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_corclass_leasion2.shape
# Out:
# (501, 502, 38)

# %%
pixel_corclass_leasion2 = img_corclass_leasion2[250,350]
pixel_corclass_leasion3 = img_corclass_leasion2[450,120]

# %%
img_corclass_leasion3 = open_image(r'HSI14\HSI14_Lesional\FOV4__14L__out.hdr')

# %%
lib_corclass_leasion3 = envi.open(r'HSI14\HSI14_Lesional\FOV4__14L__out.hdr')

# %%
lib_corclass_leasion3
# Out:
# 	Data Source:   '.\HSI14\HSI14_Lesional\FOV4__14L__out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_corclass_leasion3.shape
# Out:
# (501, 502, 38)

# %%
pixel_corclass_leasion4 = img_corclass_leasion3[100,450]
pixel_corclass_leasion5 = img_corclass_leasion3[222,333]

# %%
img_corclass_leasion4 = open_image(r'HSI9\HSI9_Lesional\9L_FOV3out.hdr')

# %%
lib_corclass_leasion4 = envi.open(r'HSI9\HSI9_Lesional\9L_FOV3out.hdr')

# %%
lib_corclass_leasion4
# Out:
# 	Data Source:   '.\HSI9\HSI9_Lesional\9L_FOV3out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_corclass_leasion4.shape
# Out:
# (501, 502, 38)

# %%
pixel_corclass_leasion6 = img_corclass_leasion4[357,221]
pixel_corclass_leasion7 = img_corclass_leasion4[435,142]

# %%
img_corclass_leasion5 = open_image(r'HSI10\HSI10_Lesional\10L_FOV2out.hdr')

# %%
lib_corclass_leasion5 = envi.open(r'HSI10\HSI10_Lesional\10L_FOV2out.hdr')

# %%
lib_corclass_leasion5
# Out:
# 	Data Source:   '.\HSI10\HSI10_Lesional\10L_FOV2out.bsq'
# 	# Rows:            501
# 	# Samples:         502
# 	# Bands:            38
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
img_corclass_leasion5.shape
# Out:
# (501, 502, 38)

# %%
pixel_corclass_leasion8 = img_corclass_leasion5[247,105]
pixel_corclass_leasion9 = img_corclass_leasion5[55,322]

# %%
plt.plot(spectrum, pixel_corclass_leasion2, color='purple')
plt.plot(spectrum, pixel_corclass_leasion3, color='orange')
plt.plot(spectrum, pixel_corclass_leasion4, color='green')
plt.plot(spectrum, pixel_corclass_leasion5, color='blue')
plt.plot(spectrum, pixel_corclass_leasion6, color='yellow')
plt.plot(spectrum, pixel_corclass_leasion7, color='magenta')
plt.plot(spectrum, pixel_corclass_leasion8, color='red')
plt.plot(spectrum, pixel_corclass_leasion9, color='black')
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.title('Spectral Distribution of Lesional (Correct) Samples')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')

# %%
img_leasion4 = open_image(r'HSI3\HSI3_Nonlesional\3N_FOV5out.hdr')

# %%
pixel_leasion_2 = img_leasion[100,400]

# %%
plt.plot(spectrum, pixel_leasion, color='black')
plt.xlabel('Wavelength')
plt.ylabel('Spectral Intensity (14-bit)')
plt.title('Spectral Distribution of "Lesional" Sample')
plt.xlim(left=350)
plt.xlim(right=750)
plt.axvline(x=450, color='blue', linestyle='--')
plt.axvline(x=485, color='blue', linestyle='--')
plt.axvline(x=500, color='green', linestyle='--')
plt.axvline(x=565, color='green', linestyle='--')
plt.axvline(x=625, color='red', linestyle='--')
plt.axvline(x=740, color='red', linestyle='--')
